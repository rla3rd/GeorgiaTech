# %%
import glob
import mne
from mne.time_frequency import psd_welch
import os
import numpy as np
import findspark
findspark.init()

import pyspark

from pyspark.sql import SparkSession
from pyspark.sql import SQLContext


spark = SparkSession \
    .builder \
    .master('local[*]') \
    .config("spark.driver.memory", "2g") \
    .appName("sleepdata") \
    .getOrCreate()
sc = spark.sparkContext

def eeg_power_band(epochs):
    """EEG relative power band feature extraction.

    This function takes an ``mne.Epochs`` object and creates EEG features based
    on relative power in specific frequency bands that are compatible with
    scikit-learn.

    Parameters
    ----------
    epochs : Epochs
        The data.

    Returns
    -------
    X : numpy array of shape [n_samples, 5]
        Transformed data.
    """
    # specific frequency bands
    FREQ_BANDS = {"delta": [0.5, 4.5],
                  "theta": [4.5, 8.5],
                  "alpha": [8.5, 11.5],
                  "sigma": [11.5, 15.5],
                  "beta": [15.5, 30]}

    psds, freqs = psd_welch(epochs, picks='eeg', fmin=0.5, fmax=30.)
    # Normalize the PSDs
    psds /= np.sum(psds, axis=-1, keepdims=True)

    X = []
    for fmin, fmax in FREQ_BANDS.values():
        psds_band = psds[:, :, (freqs >= fmin) & (freqs < fmax)].mean(axis=-1)
        X.append(psds_band.reshape(len(psds), -1))

    return np.concatenate(X, axis=1)

os.chdir('/media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/')
files = glob.glob('*.edf')
files = np.array(files)

# taken from raw.info in the loop below
cassette_mapping = {
    'EOG horizontal': 'eog',
    'Resp oro-nasal': 'misc',
    'EMG submental': 'misc',
    'Temp rectal': 'misc',
    'Event marker': 'misc'}

telemetry_mapping = {
    'EOG horizontal': 'eog',
    'EMG submental': 'misc',
    'Marker': 'misc'}

annotation_desc_2_event_id = {'Sleep stage W': 1,
                              'Sleep stage 1': 2,
                              'Sleep stage 2': 3,
                              'Sleep stage 3': 4,
                              'Sleep stage 4': 4,
                              'Sleep stage R': 5}

event_ids = {
    'Sleep stage W': 1,
    'Sleep stage 1': 2,
    'Sleep stage 2': 3,
    'Sleep stage 3/4': 4,
    'Sleep stage R': 5}

patient_ids = []
rdd = None
for patient_files in files:
    if patient_files[:7] not in patient_ids:
        patient_ids.append(patient_files[:7])
for patient_id in patient_ids:
    files = glob.glob(f'{patient_id}*')
    for file in files:
        if 'PSG' in file:
            raw = mne.io.read_raw_edf(file)
            # print(raw.info)
        else:
            annot = mne.read_annotations(file)
    
    raw.set_annotations(annot, emit_warning=False)
    raw.set_channel_types(telemetry_mapping)
    # raw.plot(duration=60, scalings='auto')
    #print(patient_id, psg, hypnogram)
    events, _ = mne.events_from_annotations(
        raw, event_id=annotation_desc_2_event_id, chunk_duration=30.)

    tmax = 30. - 1. / raw.info['sfreq'] 
    
    epochs = mne.Epochs(raw=raw, events=events,
                          event_id=event_ids, tmin=0., tmax=tmax, baseline=None, on_missing='ignore')
    
    epochs.drop_bad()
    
    y = epochs.events[:, 2]
    bands = eeg_power_band(epochs)
    
    # remove nan's from eeg_power_band transform
    nan_idx = np.argwhere([np.any(np.isnan(x)) for x in bands]).flatten()
    for idx in np.flip(nan_idx):
        bands  = np.delete(bands, idx, axis=0)
        y = np.delete(y, idx)
    # print(bands.shape, y.shape, bands, y)
    
    # combine inputs and labels into the rdd
    y = y[:, None]
    print(bands.shape, y.shape)
    bands_y = zip(bands, y)
    if rdd is None:
        rdd = sc.parallelize(bands_y)
    else:
        bands_y = sc.parallelize(bands_y)
        rdd = rdd.union(bands_y)

results = rdd.collect()
X = np.array([row[0] for row in results])
y = np.array([row[1][0] for row in results])
# Out:
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7011J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 1092 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 1092 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 1092 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (1092, 10) (1092, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7012J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 1040 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 1040 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 1040 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (1040, 10) (1040, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7021J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 920 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 920 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 920 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (920, 10) (920, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7022J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 944 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 944 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 944 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (944, 10) (944, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7041J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 1007 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 1007 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 1007 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (1007, 10) (1007, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7042J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 1130 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 1130 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 1130 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (1130, 10) (1130, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7051J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 1018 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 1018 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 1018 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (1014, 10) (1014, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7052J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 1034 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 1034 events and 3000 original time points ...
# /home/ralbright/anaconda3/envs/pytorch/lib/python3.7/site-packages/ipykernel_launcher.py:49: RuntimeWarning: divide by zero encountered in true_divide
# /home/ralbright/anaconda3/envs/pytorch/lib/python3.7/site-packages/ipykernel_launcher.py:49: RuntimeWarning: invalid value encountered in true_divide
# 0 bad epochs dropped
# Loading data for 1034 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (1032, 10) (1032, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7061J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 1008 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 1008 events and 3000 original time points ...
# /home/ralbright/anaconda3/envs/pytorch/lib/python3.7/site-packages/ipykernel_launcher.py:49: RuntimeWarning: invalid value encountered in true_divide
# 0 bad epochs dropped
# Loading data for 1008 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (1008, 10) (1008, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7062J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 952 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 952 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 952 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (952, 10) (952, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7071J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 821 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 821 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 821 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (821, 10) (821, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7122J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 945 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 945 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 945 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (945, 10) (945, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7131J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 859 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 859 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 859 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (859, 10) (859, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7132J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 852 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 852 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 852 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (852, 10) (852, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7141J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 858 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 858 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 858 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (858, 10) (858, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7142J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 873 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 873 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 873 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (873, 10) (873, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7151J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 897 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 897 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 897 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (892, 10) (892, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7152J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 1045 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 1045 events and 3000 original time points ...
# /home/ralbright/anaconda3/envs/pytorch/lib/python3.7/site-packages/ipykernel_launcher.py:49: RuntimeWarning: divide by zero encountered in true_divide
# /home/ralbright/anaconda3/envs/pytorch/lib/python3.7/site-packages/ipykernel_launcher.py:49: RuntimeWarning: invalid value encountered in true_divide
# 0 bad epochs dropped
# Loading data for 1045 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (1045, 10) (1045, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7161J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 1057 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 1057 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 1057 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (1057, 10) (1057, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7162J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 988 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 988 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 988 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (988, 10) (988, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7171J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 964 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 964 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 964 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (964, 10) (964, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7172J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 1005 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 1005 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 1005 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (1002, 10) (1002, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7181J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 959 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 959 events and 3000 original time points ...
# /home/ralbright/anaconda3/envs/pytorch/lib/python3.7/site-packages/ipykernel_launcher.py:49: RuntimeWarning: divide by zero encountered in true_divide
# /home/ralbright/anaconda3/envs/pytorch/lib/python3.7/site-packages/ipykernel_launcher.py:49: RuntimeWarning: invalid value encountered in true_divide
# 0 bad epochs dropped
# Loading data for 959 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (959, 10) (959, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7182J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 967 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 967 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 967 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (967, 10) (967, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7191J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 955 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 955 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 955 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (955, 10) (955, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7192J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 931 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 931 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 931 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (931, 10) (931, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7201J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 921 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 921 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 921 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (921, 10) (921, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7202J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 898 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 898 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 898 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (898, 10) (898, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7211J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 1077 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 1077 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 1077 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (1077, 10) (1077, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7212J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 1010 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 1010 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 1010 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (1010, 10) (1010, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7221J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 1033 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 1033 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 1033 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (1033, 10) (1033, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7222J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 951 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 951 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 951 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (951, 10) (951, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7241J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 1021 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 1021 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 1021 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (1021, 10) (1021, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7242J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 939 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 939 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 939 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (939, 10) (939, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7072J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 914 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 914 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 914 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (914, 10) (914, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7081J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 966 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 966 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 966 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (966, 10) (966, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7082J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 931 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 931 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 931 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (931, 10) (931, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7091J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 943 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 943 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 943 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (943, 10) (943, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7092J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 923 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 923 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 923 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (923, 10) (923, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7101J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 1042 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 1042 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 1042 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (1042, 10) (1042, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7102J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 980 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 980 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 980 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (980, 10) (980, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7111J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 1017 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 1017 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 1017 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (1017, 10) (1017, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7112J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 978 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 978 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 978 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (978, 10) (978, 1)
# Extracting EDF parameters from /media/data/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7121J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 1026 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 1026 events and 3000 original time points ...
# 0 bad epochs dropped
# Loading data for 1026 events and 3000 original time points ...
# Effective window size : 2.560 (s)
# (1026, 10) (1026, 1)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
model = RandomForestClassifier(n_estimators=10, random_state=42)
model.fit(X, y)
y_pred = model.predict(X)
print(confusion_matrix(y, y_pred))
# Out:
# [[ 4396    11     0     0     2]
#  [   41  3531    30     0    51]
#  [    8    14 19772    30    27]
#  [    3     0   152  6258     2]
#  [    5    23   174     3  8144]]
